# %%
import torch
import matplotlib.pyplot as plt
import sys
sys.path.append("../")

from src.test_pupils import get_polar_ck
from src.pupil import VectorialPolarPupil, VectorialCartesianPupil
from src.testers import VectorPolarTester
import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
e0x = 2.0 * np.random.rand() - 1.0
e0y = 2.0 * np.random.rand() - 1.0
ck = get_polar_ck(4)
pupil_p = VectorialPolarPupil(e0x, e0y, zernike_coefficients=ck)

N = 2*16+1
err, E_ref, E_num = VectorPolarTester.eval_error(N, pupil_p, True)

# %%
VectorPolarTester.plot_convergence(pupil_p)
# Out:
# ...
# 100%|██████████| 19/19 [1:13:10<00:00, 231.10s/it]
