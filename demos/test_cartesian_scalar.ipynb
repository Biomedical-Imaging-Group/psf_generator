# %%
import torch
import matplotlib.pyplot as plt
import sys
sys.path.append("../")

from src.testers import ScalarCartesianTester, polar_exp

# %load_ext autoreload
# %autoreload 2

# %%
Ep_ref, Ep_num = ScalarCartesianTester.eval_error(64 + 1, polar_exp, plot=True)[1:]

# %%
ScalarCartesianTester.plot_convergence(polar_exp)
# Out:
# ...
# 100%|██████████| 19/19 [02:53<00:00,  9.14s/it]
