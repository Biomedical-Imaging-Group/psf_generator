# %%
import torch
import matplotlib.pyplot as plt
import sys
sys.path.append("../")

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.pupil import VectorialCartesianPupil
from src.testers import VectorCartesianTester

pupil = VectorialCartesianPupil(n_pix_pupil=5)
_, E_c_ref, E_c_num = VectorCartesianTester.eval_error(32, pupil, True)

# %%
VectorCartesianTester.plot_convergence(pupil,Ns=[3,5,9,13,21,35,55])
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# 100%|██████████| 7/7 [02:06<00:00, 18.13s/it]
